# %%
aca_gemma4_31b_it_a100_fqdn = ! terraform output -raw aca_gemma4_31b_it_a100_fqdn
aca_gemma4_31b_it_a100_fqdn = aca_gemma4_31b_it_a100_fqdn.n
print("LLM Endpoint:", aca_gemma4_31b_it_a100_fqdn)

aca_qwen_36_35b_a100_fqdn = ! terraform output -raw aca_qwen_36_35b_a100_fqdn
aca_qwen_36_35b_a100_fqdn = aca_qwen_36_35b_a100_fqdn.n
print("LLM Endpoint:", aca_qwen_36_35b_a100_fqdn)
# Out:
# LLM Endpoint: gemma-4-31b-it-a100.calmsand-39553c09.swedencentral.azurecontainerapps.io
# LLM Endpoint: qwen-3-6-35b-a100.calmsand-39553c09.swedencentral.azurecontainerapps.io

# %%
from openai import OpenAI

client = OpenAI(
    # base_url=f"http://{aca_gemma4_31b_it_a100_fqdn}/v1",
    base_url=f"http://{aca_qwen_36_35b_a100_fqdn}/v1",
    api_key="EMPTY"
)

print(client.models.list())

response = client.chat.completions.create(
    # model="google/gemma-4-31B-it", 
    model="Qwen/Qwen3.6-35B-A3B",
    messages=[
        {"role": "user", "content": "Tell me about yourself."}
    ],
    max_tokens=1024,
    temperature=1.0
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[6], line 9
#       5     base_url=f"http://{aca_qwen_36_35b_a100_fqdn}/v1",
#       6     api_key="EMPTY"
#       7 )
#       8
# ----> 9 print(client.models.list())
#      10
#      11 response = client.chat.completions.create(
#      12     # model="google/gemma-4-31B-it",
#
# File c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\resources\models.py:98, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      84 def list(
#      85     self,
#      86     *,
#    (...)     92     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#      93 ) -> SyncPage[Model]:
#      94     """
#      95     Lists the currently available models, and provides basic information about each
#      96     one such as the owner and availability.
#      97     """
# ---> 98     return self._get_api_list(
#      99         "/models",
#     100         page=SyncPage[Model],
#     101         options=make_request_options(
#     102             extra_headers=extra_headers,
#     103             extra_query=extra_query,
#     104             extra_body=extra_body,
#     105             timeout=timeout,
#     106             security={"bearer_auth": True},
#     107         ),
#     108         model=Model,
#     109     )
#
# File c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\_base_client.py:1418, in SyncAPIClient.get_api_list(self, path, model, page, body, options, method)
#    1407 def get_api_list(
#    1408     self,
#    1409     path: str,
#    (...)   1415     method: str = "get",
#    1416 ) -> SyncPageT:
#    1417     opts = FinalRequestOptions.construct(method=method, url=path, json_data=body, **options)
# -> 1418     return self._request_api_list(model, page, opts)
#
# File c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\_base_client.py:1217, in SyncAPIClient._request_api_list(self, model, page, options)
#    1213     return resp
#    1215 options.post_parser = _parser
# -> 1217 return self.request(page, options, stream=False)
#
# File c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: stream timeout
