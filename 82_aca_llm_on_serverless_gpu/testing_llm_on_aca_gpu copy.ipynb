# %% [markdown]
# # Testing hosted LLMs on Azure Container Apps (ACA) with serverless GPU

# %%
# %pip install openai
# Out:
# Requirement already satisfied: openai in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.41.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai) (4.68.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\azureuser\AppData\Roaming\Python\Python314\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in C:\Users\azureuser\AppData\Roaming\Python\Python314\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Get the LLM model endpoints.

# %%
aca_gemma4_31b_it_a100_fqdn = ! terraform output -raw aca_gemma4_31b_it_a100_fqdn
aca_gemma4_31b_it_a100_fqdn = aca_gemma4_31b_it_a100_fqdn.n
print("👉🏻 Gemma4 31B IT Endpoint:", aca_gemma4_31b_it_a100_fqdn)

aca_qwen_36_35b_a100_fqdn = ! terraform output -raw aca_qwen_36_35b_a100_fqdn
aca_qwen_36_35b_a100_fqdn = aca_qwen_36_35b_a100_fqdn.n
print("👉🏻 Qwen 36 35B Endpoint:", aca_qwen_36_35b_a100_fqdn)

# aca_llm_fqdn = aca_gemma4_31b_it_a100_fqdn
aca_llm_fqdn = aca_qwen_36_35b_a100_fqdn

# llm_model = "google/gemma-4-31B-it"
llm_model = "Qwen/Qwen3.6-35B-A3B"
# Out:
# 👉🏻 Gemma4 31B IT Endpoint: gemma-4-31b-it-a100.calmsand-39553c09.swedencentral.azurecontainerapps.io
# 👉🏻 Qwen 36 35B Endpoint: qwen-3-6-35b-a100.calmsand-39553c09.swedencentral.azurecontainerapps.io

# %% [markdown]
# ### Make a simple OpenAI call to the LLM serverless GPU endpoint to test if it is working.

# %%
from openai import AsyncOpenAI

client = AsyncOpenAI(
    base_url=f"http://{aca_llm_fqdn}/v1",
    api_key="EMPTY"
)

print(await client.models.list())

async with client.chat.completions.stream(
    model=llm_model,
    messages=[
        {"role": "user", "content": "Tell me about yourself."}
    ],
    max_tokens=3000,
    temperature=1.0,
) as stream:
    async for event in stream:
        if event.type == "content.delta":
            print(event.delta, end="", flush=True)

# %% [markdown]
# Add telemetry to review the performance of the LLM serverless GPU endpoint.

# %%
from openai import AsyncOpenAI
import time

client = AsyncOpenAI(
    base_url=f"http://{aca_llm_fqdn}/v1",
    api_key="EMPTY"
)

print(await client.models.list())

start = time.perf_counter()

async with client.chat.completions.stream(
    model=llm_model,
    messages=[
        {"role": "user", "content": "Tell me about yourself."}
    ],
    max_tokens=3000,
    temperature=1.0,
    stream_options={"include_usage": True},
) as stream:
    async for event in stream:
        if event.type == "content.delta":
            print(event.delta, end="", flush=True)
            
elapsed = time.perf_counter() - start

# Token consumption is available on the final completion
completion = await stream.get_final_completion()
usage = completion.usage
tokens_per_second = usage.completion_tokens / elapsed if elapsed > 0 else 0
print("\n\n--- Token usage ---")
print(f"Prompt tokens:     {usage.prompt_tokens}")
print(f"Completion tokens: {usage.completion_tokens}")
print(f"Total tokens:      {usage.total_tokens}")
print(f"Elapsed time:      {elapsed:.2f} s")
print(f"Throughput:        {tokens_per_second:.2f} tokens/s")
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[3], line 9
#       5     base_url=f"http://{aca_llm_fqdn}/v1",
#       6     api_key="EMPTY"
#       7 )
#       8
# ----> 9 print(await client.models.list())
#      10
#      11 start = time.perf_counter()
#      12
#
# File c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\_base_client.py:309, in AsyncPaginator._get_page(self)
#     305     return resp
#     307 self._options.post_parser = _parser
# --> 309 return await self._client.request(self._page_cls, self._options)
#
# File c:\Users\azureuser\AppData\Local\Programs\Python\Python314\Lib\site-packages\openai\_base_client.py:1716, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1713             await err.response.aread()
#    1715         log.debug("Re-raising status error")
# -> 1716         raise self._make_status_error_from_response(err.response) from None
#    1718     break
#    1720 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: stream timeout

# %% [markdown]
# ## Image Understanding
#
# Gemma 4 natively understands images via its custom vision encoder with configurable resolution (utilizing native vision blocks).
# Let's test with this sample image.
#
# ![Image](./images/resources.png)

# %%
from openai import AsyncOpenAI
import time

client = AsyncOpenAI(
    base_url=f"http://{aca_llm_fqdn}/v1",
    api_key="EMPTY"
)

start = time.perf_counter()

async with client.chat.completions.stream(
    model=llm_model,
        messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://github.com/HoussemDellai/aca-course/blob/main/82_aca_llm_on_serverless_gpu/images/resources.png?raw=true"
                    },
                },
                {"type": "text", "text": "Describe this image in detail."},
            ],
        }
    ],
    max_tokens=3000,
    temperature=1.0,
    stream_options={"include_usage": True},
) as stream:
    async for event in stream:
        if event.type == "content.delta":
            print(event.delta, end="", flush=True)

elapsed = time.perf_counter() - start

# Token consumption is available on the final completion
completion = await stream.get_final_completion()
usage = completion.usage
tokens_per_second = usage.completion_tokens / elapsed if elapsed > 0 else 0
print("\n\n--- Token usage ---")
print(f"Prompt tokens:     {usage.prompt_tokens}")
print(f"Completion tokens: {usage.completion_tokens}")
print(f"Total tokens:      {usage.total_tokens}")
print(f"Elapsed time:      {elapsed:.2f} s")
print(f"Throughput:        {tokens_per_second:.2f} tokens/s")
# Out:
# A screenshot showing a list of cloud resources within a management console, likely Azure. The interface is in dark mode with a black background and light-colored text.
#
# The image displays a table with three columns: a checkbox column on the left, a "Name" column in the middle, and a "Type" column on the right. Each row represents a specific resource, consisting of an icon, the resource name, an ellipsis button (`...`) for more options, and the resource type.
#
# The resources listed are as follows:
#
# *   **Dashboard-06-22-2026-15-58**: Azure Monitor dashboards with Grafana (Icon: a yellow/orange graph)
# *   **gemma-4-31b-it-a100**: Container App (Icon: a purple cube)
# *   **open-webui**: Container App (Icon: a purple cube)
# *   **qwen-3-6-35b-a100**: Container App (Icon: a purple cube)
# *   **aca-job-download-models**: Container App Job (Icon: a purple cube)
# *   **aca-env-gpu-llm**: Container Apps Environment (Icon: a purple grid)
# *   **workspace-aca-555**: Log Analytics workspace (Icon: a blue grid/chart)
# *   **nic-pe-storage-account**: Network Interface (Icon: a green network card)
# *   **privatelink.file.core.windows.net**: Private DNS zone (Icon: a blue DNS globe)
# *   **pe-storage-account**: Private endpoint (Icon: a blue network node)
# *   **storage4llm4aca**: Storage account (Icon: a blue cylinder/disk)
# *   **vnet-aca**: Virtual network (Icon: a blue double-ended arrow)
#
# --- Token usage ---
# Prompt tokens:     288
# Completion tokens: 403
# Total tokens:      691
# Elapsed time:      18.00 s
# Throughput:        22.39 tokens/s

# %% [markdown]
# ## Video Understanding
#
# Video understanding is supported via a custom processing pipeline (available in this vLLM branch) that extracts video frames and pairs them with text prompts for the vision tower.
# Make sure to launch the container with the `--limit-mm-per-prompt` flag to allow video inputs (e.g. `--limit-mm-per-prompt video=1` to allow 1 video input per prompt). In this example, this was already done in the Terraform template.

# %%
from openai import AsyncOpenAI

client = AsyncOpenAI(
    base_url=f"http://{aca_llm_fqdn}/v1", 
    api_key="EMPTY"
)

start = time.perf_counter()

async with client.chat.completions.stream(
    model = llm_model,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "video_url",
                    "video_url": {
                        "url": "https://storage4swc.blob.core.windows.net/llm-videos/000.%20Why%20we%20need%20AI%20Agents%20-%20an%20LLM%20can%20think%20and%20an%20AI%20Agent%20can%20act_ALTERED.mp4?sp=r&st=2026-06-22T22:48:47Z&se=2026-12-18T08:03:47Z&spr=https&sv=2026-02-06&sr=b&sig=MFEPFSqRZXdAh9ejErLNxFbksmYtWZ9WqQBS%2BXY3f7Y%3D"
                    },
                },
                {
                    "type": "text", 
                    "text": "Summarize what happens in this video."
                 },
            ],
        }
    ],
    max_tokens=1024,
    temperature=1.0,
    stream_options={"include_usage": True},
) as stream:
    async for event in stream:
        if event.type == "content.delta":
            print(event.delta, end="", flush=True)

# Token consumption is available on the final completion
completion = await stream.get_final_completion()
usage = completion.usage
tokens_per_second = usage.completion_tokens / elapsed if elapsed > 0 else 0
print("\n\n--- Token usage ---")
print(f"Prompt tokens:     {usage.prompt_tokens}")
print(f"Completion tokens: {usage.completion_tokens}")
print(f"Total tokens:      {usage.total_tokens}")
print(f"Elapsed time:      {elapsed:.2f} s")
print(f"Throughput:        {tokens_per_second:.2f} tokens/s")
# Out:
# This presentation, titled **"Building AI Agents with Langchain and Microsoft Foundry,"** delivered by Houssem Dellai, a Cloud Solution Architect at Microsoft, provides a high-level conceptual overview of developing production-ready AI agents on Azure.
#
# The key points covered in the presentation include:
#
# *   **Learning Objectives:** The session aims to teach how to build the first agent, equip agents with tools (defining custom tools and function calls), connect via Model Context Protocol (MCP), implement code execution and memory, maintain human-in-the-loop control, and orchestrate/observe agents using LangSmith.
# *   **Why AI Agents?:** The presenter argues that a standalone Large Language Model (LLM) is not enough because it is frozen in time, can only produce text, and lacks long-term memory. An "Agent" adds "senses and memory," allowing the LLM to access live private data, take actions (via APIs/code), remember context, and iterate/self-correct using the ReAct pattern.
# *   **Anatomy of an AI Agent:** A diagram illustrates the LLM as the central "reasoning" core, surrounded by supporting components:
#     *   **Human in the loop:** For validation and input.
#     *   **DB/Memory:** For history and user profiles.
#     *   **Sandbox:** For isolated code execution (Shell/PS1).
#     *   **MCP servers:** For REST APIs and self-hosted services.
#     *   **Tools/Function calling:** To call Python or other APIs.
# *   **Development Frameworks:** Several frameworks are listed for building agents, including LangChain/LangGraph (the focus of the course), Microsoft Agent Framework, CrewAI, Open AI Agents SDK, Google ADK, LlamaIndex, and the Claude Agent SDK.
# *   **LLM Providers:** The presentation notes that while agents can use models from various providers (OpenAI, Anthropic, Google AI Studio, AWS Bedrock, DeepSeek, Mistral, Cohere), this specific course utilizes **Microsoft Foundry**, which provides an Azure-hosted catalog of models including OpenAI, Llama, Mistral, and Phi.
#
# --- Token usage ---
# Prompt tokens:     2421
# Completion tokens: 452
# Total tokens:      2873
# Elapsed time:      18.00 s
# Throughput:        25.11 tokens/s
